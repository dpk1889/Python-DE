# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# python is cass sensitive

# %%
print("hello world")
print(55 + 98)
print(34)

# Variables
name = "deepak"
aged = 26
salary = 60.5

print(name)
print(aged)
print(salary)

print(type(name))
print(type(aged))
print(type(salary))

# %% [markdown]
# 1. datatypes in python
# 2. integers
# 3. strings
# 4. float
# 5. boolean - True or False
# 6. None = no value stored

# %%
a= None
b= False

print(type(a))
print(type(b))

# %% [markdown]
# 1. python keywords
# 2. reserved words cant be named as variable names like else,none,with,if,while,import,raise,finally,lambda,None,nonlocal

# %%
a=10
b=20
sum=a+b
print(a+b)
print(sum)

# %%
# single comments 
# multiline comments - triple comments 
#arithmetic operators
a=10
b=2
sum=a+b
diff=a-b
mult=a*b
div=a/b
modulo=a%b
power1=(a**b)
power2=(b^a)

print(sum)
print(diff)
print(mult)
print(div)
print(modulo)
print(power1)
print(power2)

# %%
# relational operators 
a= 50
b=20

print(a==b)
print(a!=b)
print(a>b)
print(a>=b)

# %%
#assignment operator
a=10
num=11
num=num+a
print(num)
print(a**5)

# %%
#logical operators 
# and,or,not 
a=50
b=20
print(not(a>b))
print(a>b and not(a<b))

# %%
#type conversion 
#type conversion - interpretor automatically 
# type casting - explicitly done by user/coder - works as valid like name cant be casted to int/float 

a=10
b=2
c="123"
a/b
print(a+b+int(c))

# %%
# user input 
input("enter your name")
name=input("my name")

# %%
# input always takes as string 
age=input("age")
print(type(age))
print(type(int(age)))

# %% [markdown]
# **string**

# %%
str='i am learning ml and llm'
str2="new version\nuploading"
str3='''latest'''

print(str)
print(str2)

# %%
#escape sequence characters 
#concatenation 

print(str+ " " +str2)
len(str2+str3)
len(str2)
len(str3)

# %%
#indexing 
#string index start from zero and ends at n-1 i.e len -1 every thing has index even newline, escape sequences 
str1="all 3he best"
print(str1[4])
print(str1[5])

# %%
#slicing
#string(start index:ending index,steps )
str="this is really tough"
str2='deeps'
print(str[4:])
print(str[0:4])
print(str[:20])
print(str2[::-1])
print(str2[-5:-1])

# %%
# string fucntions 
str="i am learning python"
print(str.endswith("on"))
str2=str.capitalize() # creates new string as does not impact original string 
print(str2)
str.replace("a","A")
str.find("am")

# %%
str.find("q")

# %%
str.count("am")

# %%
str=input("enter string")
print(len(str))
print(str.count("i"))

# %%
#conditional statements
# elif always executes after if 
aged=input("your age")
age=int(aged)
if age>18 and age<60:
    print("working population")
elif age >20:
    print("senior" )
elif age >60:
    print("not senior" )    
else:
    print("adult")

# %%
aged=input("your age")
age=int(aged)
if age>18 and age<60:
    print("working population")
if age >20:
    print("senior" )
if age >60:
    print("not senior" )    
else:
    print("adult")

# %%
#nesting 
# statement within the statement 
age=89
if age>18:
    if age>80:
        print("cannot drive")
    else: print("can drive")    
else: print("cannot drive buddy")

# %%
a=int(input())
b=int(input())
c=int(input())
if(a>=b and a>=c):
    print(a)
elif(b>=c):
    print(b)
else:
    print(c)

# %%
#list and tuple in python
marks=[10,13,15,19,11,18,17,20,15.5,16.5]
print(marks)
print(type(marks))
print(marks[1])

# %%
print(marks[2:6])
print(marks[::-1])
print(marks[-15:-3])

# %%
list=[10,20,30]
list.append(39)
list

# %%
list.sort()
list

# %%
list.sort(reverse=True)
list

# %%
list.insert(1,59)
list

# %%
lst=['a','h','k','n','b','e']
lst.sort()
lst

# %%
lst.reverse()
lst

# %%
lst.pop(3)
lst

# %%
lst=[10,12,13,19,102]
lst.remove(12)
lst

# %%
#tuple - immutable sequence of values 

tup=(2,3,4,5,5,7)
print(tup)
print(type(tup))
print(tup[4])

# %%
tup=(1)
tup2=(2,) # single element tuple needs comma 
print(type(tup))
print(type(tup2))

# %%
tup=(2,3,4,5,5,7)
tup.index(4)

# %%
print(tup.count(5))

# %%
a=input()
b=input()
c=input()
lst=[]
lst.append(a)
lst.append(b)
lst.append(c)
print(lst)

# %%
#palindrome list 
lst=[1,2,3,2,1,2]
lst1=lst.copy()
lst1.reverse()
if lst==lst1:
    print("palindrome")
else:
    print("not palindrome")

# %%
grade=('c','d','a','a','b','b','a')
print(grade.count('a'))

# %%
del list
grade2=list(grade)
grade2.sort()
grade2

# %%
#dictionary and sets 
# built in datatypes 
# used to store key value pairs , ordered, mutable,dont allow duplicate keys 
#keys cant be list and dictionary

dct={
    "name":'deepak',
    "age":26,
    "salary":200000
}
print(dct["age"])
dct["age"]=32
dct

# %%
student={
    'name':'deepak',
    "subjects":{
        "maths":30,
        'phy':33,
        'chem':26
    }
}
student

# %%
#dict methods 
mydict={
    'name':'deepak',
    "subjects":{
        "maths":30,
        'phy':33,
        'chem':26
    }
}
print(mydict.keys())
print(len(mydict.keys()))

# %%
mydict.values()

# %%
mydict.items()
#return tuples key and value
print(list(mydict.items()))
pair=list(mydict.items())
print(pair[0])
pair[1]

# %%
mydict.get('name')

# %%
#print(mydict['name2'])
#to avoid error we use methods to continue flow of code execution

# %%
print(mydict.get('name2'))

# %%
student.update({"city":'hyd'})
print(student)

# %%
new_dict={'city':'hyd',"pin":829,'name':'deepak kumar'}
student.update(new_dict)
print(student)
#values will be overwritten

# %%
#set - collection of unordered items 
# each element is unique and immutable -> list and dict cant be passed 

collection={1,2,3,4,1,1,"hello","world",'hello'}
print(collection)
print(len(collection))

# %%
collection2={}
collection3=set()
print(type(collection2))
print(type(collection3))

# %%
collection3=set()
collection3.add(1)
collection3.add(2)
collection3.add(1)
collection3.add(1)
collection3.add(3)
print(collection3)

# %%
collection3.remove(1)
print(collection3)

# %%
collection3.clear()
print(collection3)

# %%
collection4={'an','or','the','articles'}
print(collection4.pop())
print(collection4.pop())

# %%
#union and intersection
set1={1,2,3,5}
set2={2,2,34,4,5}
print(set1.union(set2))
print(set1.intersection(set2))
print(set1)

# %%
dict={}
x=input("enter phy")
dict.update({"phy":x})

x2=input("enter chem")
dict.update({"chem":x2})

x3=input("enter maths")
dict.update({"maths":x3})
print(dict)

# %%
values={9,9.0}
values
